# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The image shows the basic process of Data Science.
#
# The process is converted into three parts
#
# 1. Data where the historical data is loaded.
#
# 2. Intelligence is where Feature Engineering is a part of that includes Information Management, DS Technologies and Models.
#
# 3. Action includes loading new data into the model as well as receiving the output result.
#
#
#
# Historical data or past data from various sources are cleaned and subjected to Feature Engineering. Feature Engineering is the process of using domain knowledge to select or create significant features from the historical data relevant to the problem statement. This engineered data is divided into two sets: Train data and Test data. Data Science models are built using train data, and then the performance of the model is evaluated on the test data. This validated model is used for making various decisions on new/unseen data points.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The image shows the Data Science Process and architecture.
#
# The Historic Business data that can be used to gain business insights is loaded into the Data part. It can lead to a gain in efficiency. In Information Management, constructing and selecting features for the problem takes place. It includes Cleaning of the data and has a Distributed or parallel computing environment for handling massive amounts of data.
#
# DS Technologies contains components that create a model based on the patterns in the trainig data.
#
# Under the Models section, is where the pattern or the knowledge is extracted from the data. When new data is given to the Model, it produces the desired result (in Classification, Regression, etc.)
#
# Action part is the layer that uses the model to gain business insights.

# %% [markdown]
# The image shows the Data Science Life cycle :
#
# 1. Define the goal where you identify the problem to be solved.
#
# 2. Collect and manage data where you identify the information needed.
#
# 3. Build a model where you find patterns in the data that leads to the solution.
#
# 4. Evaluate the model, including validating whether the model solves the problem.
#
# 5. Present results and the document includes establishing how the problem can be solved.
#
# 6. Deploy model is where the model is deployed to solve the problem in the real world.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 1: Define the goal**
#
# The first step is to define a clear goal. Hence, it is important to understand the following details:
#
# * Why has the project been started? What is missing currently, and what is required?
#
# * What is being done to fix the problem, and why isn’t it working?
# What is the resource requirement?
# * What kind of data is available? Is domain expertise available within the team? What are the computational resources available/required?
# * How does the business organization plan to deploy the derived results? What kind of problems need to be addressed for successful deployment?
#
#
# **Bad loan use-case: Define the goal**
#
# The goal is to lessen the bank's losses caused by bad loans. To do this, the firm intends to create a tool to help the bank's loan officers improve their accuracy in identifying bad loan applicants, thereby lowering the number of bad loans being authorized. For this purpose, the goal defined should be to point out unambiguousness. For example, a goal that states, "The rate of loan charge-offs will be reduced by at least 10%, using a model which predicts whether loan applicants are likely to default" is preferred.

# %% [markdown]
# **Step 2: Collect and manage data**
#
# After the goal is set, the next step is to find, explore, and clean the data necessary for analysis. This stage requires a lot of time but helps in finding answers to many important questions, such as:
#
# * What all data is available?
# * Will it help in solving the problem?
# * Is the data enough to carry out analysis?
# * Is the quality of data up to the mark?
#
#
# **Bad loan use-case: Collect and manage data**
#
# * Collect the data about each loan application with relevant attributes such as status of the loan, duration, credit history of the applicant, present employment status, residing at an address since, number of dependents, and the number of active loans under the applicant’s name.
# * Collect the data across a reasonable span of time, such as one year or one decade.
# * Conduct initial exploration (using data visualization and summary statistics) and clean the data.
# * While refining the data, it may happen that the data identified earlier turns out inadequate to perform the analysis.
# * There might be a situation of encountering various new problematic areas within the data, which was disregarded earlier as not being a problem. For example, if the data set contained most of the defaulters or just a few defaulters, the analysis may result in a biased conclusion.

# %% [markdown]
# **Step 3: Build a model**
# Once the data is ready, the next step is to find meaningful insights from the data. Depending on the nature of the business problem that is to be dealt can make use of any of the following data modeling techniques to gather such insights:
#
# * Classification: Determining which among the given categories a data point falls under
# * Scoring: Predicting or estimating a quantifiable value
# * Ranking: Ordering the data points depending on the priorities involved
# * Clustering: Grouping similar items based on certain parameters
# * Finding relations: Finding associations between various features of the data
# * Characterization: Creating plots, graphs, and various reports to understand the data better
#
#
# **Bad loan use-case: Build a model**
# * In the bank scenario, the problem dealt with is classification. The bank categorizes the customers who apply for loans as probable defaulters or non-defaulters. Hence, the model must be trained so that it covers the entire range of the available data, thus, enabling it to learn about most of the probable loan defaulter cases.
# * Given the preceding requirement, a suitable approach can be decided to build the model. The choice can be from either logistic regression, naive Bayes, k-nearest neighbors, or decision trees, among other available classification techniques.
# * One must also be aware of why a model is taking a particular decision and how confident it is in its prediction. Ultimately, the model should be able to answer the question, "How likely is an applicant to be a defaulter"?

# %% [markdown]
# **Step 4: Model evaluation**
#
# Now that the model is built, you need to determine whether it meets all the goals by asking the following questions:
#
# * Is the model accurate enough for our needs?
# * Does the model meet the expectations? Is it better than the methodology currently used?
# If for either of the above questions, the answer is NO; the previous steps must be revisited.
#
#
#
# **Bad loan use-case: Model evaluation**
# * Check whether the evaluation parameters from the suggested model apply in the required scenario.
# * Proceed to calculate the model evaluation parameters (such as accuracy and precision) based on the predefined rules and observe how many predicted values match the actual values.

# %% [markdown]
# **Step 5: Present results and document**
#
# At this stage, the desirable model is created. A model that meets all the requirements and goals set at the beginning of the project. The next step is to showcase the project to various audiences as follows:
#
# * Present the details of the model to all the collaborators, clients, and sponsors.
# * Provide everyone in charge of usage and maintenance of the model, once deployed, with documentation that covers all aspects of the working of the model.
#
# Each group of people involved in the project requires a different kind of treatment when it comes to presentations and providing documentation. Hence, specific data visualization techniques must be used for each of them. What might work for one audience might not work for the other.
#
#
#
# **Bad loan use-case: Present results and document**
#
# In the bad loan scenario, the efficacy of the model must be showcased to the bank officials. For example, if our model can identify a set of bad loans that amount to 36% of the total money lost to defaulters, then emphasis should be on the same in the executive summary. In addition to this, any interesting insights uncovered, such as new auto loans are riskier than used auto loans; or fewer losses are tied to home loans, must also be presented.

# %% [markdown]
# **Step 6: Deploy model**
# The last and final step is to deploy the model. Usually, from this point, the data scientist is no longer associated with the operations of the model. But before the final handover data scientist must make sure of the following:
#
# * The model has been tested thoroughly and generalizes well.
# * The model should be able to adjust well to unforeseen environmental changes.
# * The model has been deployed in a pilot program, and any problems that cropped up at the last moment were taken care of by updating the model accordingly.
#
#
# **Bad loan use-case: Deploy model**
#
# There may arise a situation wherein experienced loan officers might veto the decision taken by the model that is manmade as it opposes their instincts. Hence, always look out for whether the model is correct or their intuition.

# %% [markdown]
# The image shows the characteristics needed for a successful Data Science project
#
# 1. A clear, verifiable and quantifiable goal
#
# 2. Set realistic expectations for all stakeholders
#
# 3. An unbiased data set covering examples that are sufficient to represent the entire data
#
# 4. The right model based on the business scenario
#
# 5. Correctly represented and deployed model to meet the predefined goal

# %% [markdown]
# # **Top 10 Data Science Real Word usecase:**
#
# Each of the above use cases are briefly described below:
#
#
# * **Churn Prediction**
#
#   Churn implies loss of customers to the competition. For any company, it costs more to acquire new customers than to retain old ones. As churn prediction aids in customer retention, it is extremely important, especially for businesses with a repeat customer base. The application of this model cuts across domains such as Banking, E-Retail, Telecom, Energy, and Utilities.
#
#
#
# * **Sentiment Analysis**
#
#   Also referred to as opinion mining, it is the process of computationally identifying what customers like and dislike about a product or a brand. A domain that relentlessly makes use of sentiment analysis is the Retail industry. Companies like Amazon, Flipkart, Reliance, and Paytm use customer feedback from social networking sites like Facebook, Twitter, etc., or their own company websites to find out what their customers are talking about and how they feel, i.e., positive, negative, or neutral. They leverage this information to reposition their products and provide better/new services.
#
#
#
# * **Online Advertisement**
#
#   The incremental growth in the complexity of the advertisement industry is due to the ease of access to the internet via a wide variety of devices around the world. This gives advertisers an opportunity to study user preferences and online trends. The insights offered to them are through this analysis which translates to actionable items on issues and opportunities such as reducing ad-blindness or optimizing cost-per-action (CPA) and click-through-rates (CTR).
#
#
#
# * **Recommendations**
#
#   Many e-retail companies like Amazon, Netflix, Spotify, Best Buy, and YouTube, among many others use recommender systems to improve a customer's shopping experience. This offers the companies a chance to gather information on customer's preferences, purchases, and other browsing patterns, which lend insights that can amplify their return on investment.
#
#
#
# * **Truth and Veracity**
#
#   In today's digital world, fake news is available in abundance and is also easily accessible. Not only does most of the population fall prey to misinformation, but it also affects businesses negatively. Data Science is used to ensure data veracity or, in other words, verify the truthfulness of data based on both accuracy and context. Companies such as Facebook, Twitter, Starbucks, Costco, and many others are combating fake news currently with the help of various data science techniques.
#
#
#
# * **News Aggregation**
#
#   A news aggregator gathers and clusters stories of the same topic from several leading news websites and traces the genuine source of a news item and what is the course of the story. It has a special interactive timeline that allows the reader to flip swiftly between headlines, refining their search by country or by specific news sites. Notable examples include Google News, Reddit, Flipboard, Pulse, etc.
#
#
#
# * **Scalability**
#
#   Scalability refers to an enterprise's ability to handle increased demands. In the corporate environment, a scalable company is one that can maintain or improve profit margins while sales volume increases. Sometimes the process is slowed down by human intervention in decisions. For example, credit operations in banks invest substantial time in assessing the creditworthiness of a client. Client management teams take a long time to suggest the right product to the customer/suggest alternatives. The client help desk takes a long time to provide the desired info to the client. If these processes can be automated, the business can scale up. Data science helps build systems like recommender systems, Chabot’s, etc., to achieve scalability.
#
#
#
# * **Content Discovery/ Search**
#
#   Content discovery involves using predictive algorithms to help make content recommendations to users based on how they search. Search engines such as Google, Bing and Yahoo, and various other platforms are now using intelligent learning mechanisms to understand user preferences to be able to suggest content that’s most suitable for them.
#
#   A few more platforms that use content discovery algorithms are Facebook and YouTube. The content that appears in an individual's Facebook news feed and the videos that appear in the "Recommended for You" section of a YouTube user's account are both altered according to each user's past behavior and personal preferences.
#
#
#
# * **Intelligent Learning**
#
#   Intelligent learning has become part of our day to day lives in various forms. For example, Google Maps uses undesignated location data from various smart devices to predict the flow of traffic in real-time. It also utilizes user-based reports on incidents that might affect traffic, like road construction and accidents, to help suggest the fastest routes for travel to users.
#
#   Another example would be ride sharing apps like Uber and Ola. They optimize the ride experience by not only minimizing the ride time but also by matching users with other passengers for the least detours in shared rides.
#
#   Other examples of intelligent learning include self-driving cars, smart-email categorization, credit card fraud detection, etc.
#
#
#
# * **Personalized Medicine**
#
#   In many cases, the success of a particular treatment for a patient’s condition cannot be predicted. Thus, many medical practitioners follow a non-optimal trial-and-error approach.
#
#   In personalized medicine, a doctor must study an individual's genes, environment, and lifestyle. This would help tailor treatments for specific medical conditions instead of a trial-and-error approach. This would also enable pharmaceutical researchers to create combination drugs targeting a specific genomic profile, increasing efficiency.
#
#   Companies that are active in the field of personalized medicine are Roche, Novartis, and Johnson & Johnson, among others.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
